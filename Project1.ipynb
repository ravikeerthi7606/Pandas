# %% [markdown]
# <a href="https://colab.research.google.com/github/ravikeerthi7606/Pandas/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame([2,32,12,1])

# %%
df
# Out:
#     0
# 0   2
# 1  32
# 2  12
# 3   1

# %%
price = pd.Series([2,32,12,1], name="Price")

# %%
price
# Out:
# 0     2
# 1    32
# 2    12
# 3     1
# Name: Price, dtype: int64

# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   inflating: deliveries.csv
#   inflating: matches.csv
